# %% [markdown]
# Data collected from:
# firearm mortality by state...cdc...https://www.cdc.gov/nchs/pressroom/sosmap/firearm_mortality/firearm.htm.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
import numpy as np
output_file = "output_data/guns_state.csv"

# %%
file_path = "Resources/data_table.csv"
guns_death_rate = pd.read_csv(file_path)
guns_death_rate.head()
# Out:
#      YEAR STATE  RATE  DEATHS                                       URL
# 0  2018.0    AL  21.8  1064.0     /nchs/pressroom/states/alabama/al.htm
# 1  2018.0    AK  21.0   155.0      /nchs/pressroom/states/alaska/ak.htm
# 2  2018.0    AZ  15.3  1147.0     /nchs/pressroom/states/arizona/az.htm
# 3  2018.0    AR  18.9   573.0    /nchs/pressroom/states/arkansas/ar.htm
# 4  2018.0    CA   7.5  3040.0  /nchs/pressroom/states/california/ca.htm

# %%
columns = ['YEAR', 'STATE', 'RATE', 'DEATHS']
tx_vs_ca_df = guns_death_rate.loc[(guns_death_rate['STATE'] == 'TX')|(guns_death_rate['STATE'] == 'CA'), columns]
tx_vs_ca_df.to_csv(output_file, index=False)
tx_vs_ca_df.head()
# Out:
#        YEAR STATE  RATE  DEATHS
# 4    2018.0    CA   7.5  3040.0
# 42   2018.0    TX  12.2  3522.0
# 54   2017.0    CA   7.9  3184.0
# 92   2017.0    TX  12.4  3513.0
# 104  2016.0    CA   7.9  3184.0

# %%
tx_vs_ca_df.plot.bar(x='YEAR')
plt.title('Texas vs California Guns-Related Death Rate and Numbers')
plt.xlabel('State')
plt.ylabel('Average Number of Death and Rate')
plt.show()

# %%
tx_vs_ca = tx_vs_ca_df.loc[:, ['STATE', 'RATE', 'DEATHS']]
tx_vs_ca = tx_vs_ca.groupby('STATE').mean()
tx_vs_ca.head()
# Out:
#             RATE       DEATHS
# STATE
# CA      7.983333  3149.666667
# TX     11.700000  3154.833333

# %%
tx_vs_ca.plot.bar()
plt.title('Texas vs California Guns-Related Death Rate and Numbers')
plt.xlabel('State')
plt.ylabel('Average Number of Death and Rate')
plt.show()
